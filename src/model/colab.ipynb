# %% [markdown]
# # KTDB OD 예측 모델 학습

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
# 내 구글 드라이브의 KTDB/src/model 폴더로 이동 
os.chdir('/content/drive/MyDrive/kt/KTDB')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### XGBoost 모델 학습

# %%
# !python train.py --model xgb --epochs 100 --batch_size 64

# %% [markdown]
# ### Deep Gravity 모델 학습

# %%
# !python train.py --model deep_gravity --epochs 50 --batch_size 128

# %% [markdown]
# ### Spatial OD MAE 모델 학습

# %%
# !python src/model/train.py --model mae1 --epochs 50 --batch_size 32
# Out:
# Starting Training...
# Dataset 초기화 완료
# Dataset 초기화 완료
# Using device: cuda
# Epoch 1/50 [Mask: 3, α: 10.0]: 100% 32/32 [00:54<00:00,  1.71s/it, loss=207, lr=2.5e-05]
# Epoch 1 Train Loss: 217.6612
# Epoch 2/50 [Mask: 3, α: 9.8]: 100% 32/32 [00:54<00:00,  1.70s/it, loss=238, lr=4.1e-05]
# Epoch 2 Train Loss: 207.3050
#   ➜ [Val] Loss: 28.6224 | RMSE: 985.74 | CPC: 0.0034
#   ➜ [Checkpoint] Best model saved! (RMSE: 985.74)
# Epoch 3/50 [Mask: 3, α: 9.6]: 100% 32/32 [00:55<00:00,  1.74s/it, loss=219, lr=6.6e-05]
# Epoch 3 Train Loss: 201.9445
# Epoch 4/50 [Mask: 3, α: 9.4]: 100% 32/32 [00:56<00:00,  1.75s/it, loss=158, lr=1.0e-04]
# Epoch 4 Train Loss: 181.8377
#   ➜ [Val] Loss: 24.8224 | RMSE: 985.72 | CPC: 0.0126
#   ➜ [Checkpoint] Best model saved! (RMSE: 985.72)
# Epoch 5/50 [Mask: 3, α: 9.2]: 100% 32/32 [00:55<00:00,  1.74s/it, loss=162, lr=1.4e-04]
# Epoch 5 Train Loss: 162.0826
# Epoch 6/50 [Mask: 3, α: 9.0]: 100% 32/32 [00:56<00:00,  1.75s/it, loss=115, lr=1.9e-04]
# Epoch 6 Train Loss: 127.0874
#   ➜ [Val] Loss: 11.7223 | RMSE: 985.29 | CPC: 0.0928
#   ➜ [Checkpoint] Best model saved! (RMSE: 985.29)
# Epoch 7/50 [Mask: 3, α: 8.8]: 100% 32/32 [00:55<00:00,  1.75s/it, loss=58.6, lr=2.4e-04]
# Epoch 7 Train Loss: 79.8490
# Epoch 8/50 [Mask: 4, α: 8.6]: 100% 32/32 [00:56<00:00,  1.76s/it, loss=45, lr=2.9e-04]
# Epoch 8 Train Loss: 47.7878
#   ➜ [Val] Loss: 8.2451 | RMSE: 984.28 | CPC: 0.1982
#   ➜ [Checkpoint] Best model saved! (RMSE: 984.28)
# Epoch 9/50 [Mask: 4, α: 8.4]: 100% 32/32 [00:56<00:00,  1.75s/it, loss=38.2, lr=3.4e-04]
# Epoch 9 Train Loss: 37.8739
# Epoch 10/50 [Mask: 4, α: 8.2]: 100% 32/32 [00:56<00:00,  1.76s/it, loss=34, lr=3.8e-04]
# Epoch 10 Train Loss: 35.9198
#   ➜ [Val] Loss: 7.2339 | RMSE: 984.29 | CPC: 0.2100
# Epoch 11/50 [Mask: 4, α: 8.0]: 100% 32/32 [00:55<00:00,  1.75s/it, loss=31.8, lr=4.2e-04]
# Epoch 11 Train Loss: 34.3122
# Epoch 12/50 [Mask: 4, α: 7.8]: 100% 32/32 [00:56<00:00,  1.75s/it, loss=25.5, lr=4.5e-04]
# Epoch 12 Train Loss: 29.8682
#   ➜ [Val] Loss: 5.9634 | RMSE: 984.12 | CPC: 0.1973
#   ➜ [Checkpoint] Best model saved! (RMSE: 984.12)
# Epoch 13/50 [Mask: 4, α: 7.6]: 100% 32/32 [00:55<00:00,  1.75s/it, loss=20, lr=4.8e-04]
# Epoch 13 Train Loss: 23.0731
# Epoch 14/50 [Mask: 4, α: 7.3]: 100% 32/32 [00:56<00:00,  1.75s/it, loss=17.4, lr=5.0e-04]
# Epoch 14 Train Loss: 18.2521
#   ➜ [Val] Loss: 3.3680 | RMSE: 978.54 | CPC: 0.3411
#   ➜ [Checkpoint] Best model saved! (RMSE: 978.54)
# Epoch 15/50 [Mask: 5, α: 7.1]: 100% 32/32 [00:56<00:00,  1.77s/it, loss=12.8, lr=5.0e-04]
# Epoch 15 Train Loss: 14.4663
# Epoch 16/50 [Mask: 5, α: 6.9]: 100% 32/32 [00:56<00:00,  1.76s/it, loss=11.6, lr=5.0e-04]
# Epoch 16 Train Loss: 11.5323
#   ➜ [Val] Loss: 2.1665 | RMSE: 975.21 | CPC: 0.3862
#   ➜ [Checkpoint] Best model saved! (RMSE: 975.21)
# Epoch 17/50 [Mask: 5, α: 6.7]: 100% 32/32 [00:56<00:00,  1.75s/it, loss=9.2, lr=5.0e-04]
# Epoch 17 Train Loss: 9.5850
# Epoch 18/50 [Mask: 5, α: 6.5]: 100% 32/32 [00:56<00:00,  1.76s/it, loss=7.85, lr=4.9e-04]
# Epoch 18 Train Loss: 8.3742
#   ➜ [Val] Loss: 1.7114 | RMSE: 970.10 | CPC: 0.4177
#   ➜ [Checkpoint] Best model saved! (RMSE: 970.10)
# Epoch 19/50 [Mask: 5, α: 6.3]: 100% 32/32 [00:56<00:00,  1.76s/it, loss=7.02, lr=4.8e-04]
# Epoch 19 Train Loss: 7.2867
# Epoch 20/50 [Mask: 5, α: 6.1]: 100% 32/32 [00:56<00:00,  1.76s/it, loss=6.5, lr=4.7e-04]
# Epoch 20 Train Loss: 6.5323
#   ➜ [Val] Loss: 1.5837 | RMSE: 968.42 | CPC: 0.4328
#   ➜ [Checkpoint] Best model saved! (RMSE: 968.42)
# Epoch 21/50 [Mask: 5, α: 5.9]: 100% 32/32 [00:56<00:00,  1.76s/it, loss=6.1, lr=4.6e-04]
# Epoch 21 Train Loss: 5.9051
# Epoch 22/50 [Mask: 6, α: 5.7]: 100% 32/32 [00:56<00:00,  1.75s/it, loss=5.63, lr=4.5e-04]
# Epoch 22 Train Loss: 5.2017
#   ➜ [Val] Loss: 1.4163 | RMSE: 966.78 | CPC: 0.4365
#   ➜ [Checkpoint] Best model saved! (RMSE: 966.78)
# Epoch 23/50 [Mask: 6, α: 5.5]: 100% 32/32 [00:56<00:00,  1.77s/it, loss=4.97, lr=4.4e-04]
# Epoch 23 Train Loss: 4.7577
# Epoch 24/50 [Mask: 6, α: 5.3]: 100% 32/32 [00:55<00:00,  1.74s/it, loss=4.19, lr=4.2e-04]
# Epoch 24 Train Loss: 4.3337
#   ➜ [Val] Loss: 1.3000 | RMSE: 957.26 | CPC: 0.4763
#   ➜ [Checkpoint] Best model saved! (RMSE: 957.26)
# Epoch 25/50 [Mask: 6, α: 5.1]: 100% 32/32 [00:56<00:00,  1.76s/it, loss=4.57, lr=4.1e-04]
# Epoch 25 Train Loss: 4.0500
# Epoch 26/50 [Mask: 6, α: 4.9]: 100% 32/32 [00:56<00:00,  1.76s/it, loss=3.71, lr=3.9e-04]
# Epoch 26 Train Loss: 3.6687
#   ➜ [Val] Loss: 1.2282 | RMSE: 957.93 | CPC: 0.4716
# Epoch 27/50 [Mask: 6, α: 4.7]: 100% 32/32 [00:56<00:00,  1.75s/it, loss=3.35, lr=3.7e-04]
# Epoch 27 Train Loss: 3.3464
# Epoch 28/50 [Mask: 6, α: 4.5]: 100% 32/32 [00:56<00:00,  1.75s/it, loss=3.03, lr=3.5e-04]
# Epoch 28 Train Loss: 3.1393
#   ➜ [Val] Loss: 1.1591 | RMSE: 956.19 | CPC: 0.4826
#   ➜ [Checkpoint] Best model saved! (RMSE: 956.19)
# Epoch 29/50 [Mask: 7, α: 4.3]: 100% 32/32 [00:55<00:00,  1.74s/it, loss=2.81, lr=3.3e-04]
# Epoch 29 Train Loss: 2.8669
# Epoch 30/50 [Mask: 7, α: 4.1]: 100% 32/32 [00:55<00:00,  1.74s/it, loss=2.79, lr=3.0e-04]
# Epoch 30 Train Loss: 2.6746
#   ➜ [Val] Loss: 1.0728 | RMSE: 948.19 | CPC: 0.4983
#   ➜ [Checkpoint] Best model saved! (RMSE: 948.19)
# Epoch 31/50 [Mask: 7, α: 3.9]: 100% 32/32 [00:56<00:00,  1.76s/it, loss=2.38, lr=2.8e-04]
# Epoch 31 Train Loss: 2.4997
# Epoch 32/50 [Mask: 7, α: 3.7]: 100% 32/32 [00:55<00:00,  1.74s/it, loss=2.24, lr=2.6e-04]
# Epoch 32 Train Loss: 2.2988
#   ➜ [Val] Loss: 1.0883 | RMSE: 941.40 | CPC: 0.5137
#   ➜ [Checkpoint] Best model saved! (RMSE: 941.40)
# Epoch 33/50 [Mask: 7, α: 3.5]: 100% 32/32 [00:56<00:00,  1.75s/it, loss=2.04, lr=2.4e-04]
# Epoch 33 Train Loss: 2.1237
# Epoch 34/50 [Mask: 7, α: 3.3]: 100% 32/32 [00:56<00:00,  1.75s/it, loss=1.94, lr=2.2e-04]
# Epoch 34 Train Loss: 1.9832
#   ➜ [Val] Loss: 1.0164 | RMSE: 924.38 | CPC: 0.5444
#   ➜ [Checkpoint] Best model saved! (RMSE: 924.38)
# Epoch 35/50 [Mask: 7, α: 3.1]: 100% 32/32 [00:56<00:00,  1.75s/it, loss=2, lr=1.9e-04]
# Epoch 35 Train Loss: 1.8324
# Epoch 36/50 [Mask: 8, α: 2.9]: 100% 32/32 [00:56<00:00,  1.76s/it, loss=1.69, lr=1.7e-04]
# Epoch 36 Train Loss: 1.6938
#   ➜ [Val] Loss: 0.9811 | RMSE: 936.03 | CPC: 0.5295
# Epoch 37/50 [Mask: 8, α: 2.7]: 100% 32/32 [00:56<00:00,  1.75s/it, loss=1.39, lr=1.5e-04]
# Epoch 37 Train Loss: 1.5645
# Epoch 38/50 [Mask: 8, α: 2.4]: 100% 32/32 [00:56<00:00,  1.76s/it, loss=1.38, lr=1.3e-04]
# Epoch 38 Train Loss: 1.4388
#   ➜ [Val] Loss: 0.9645 | RMSE: 932.25 | CPC: 0.5335
# Epoch 39/50 [Mask: 8, α: 2.2]: 100% 32/32 [00:56<00:00,  1.76s/it, loss=1.26, lr=1.1e-04]
# Epoch 39 Train Loss: 1.3219
# Epoch 40/50 [Mask: 8, α: 2.0]: 100% 32/32 [00:56<00:00,  1.75s/it, loss=1.2, lr=9.4e-05]
# Epoch 40 Train Loss: 1.2345
#   ➜ [Val] Loss: 0.9552 | RMSE: 930.73 | CPC: 0.5403
# Epoch 41/50 [Mask: 8, α: 1.8]: 100% 32/32 [00:56<00:00,  1.76s/it, loss=1.01, lr=7.7e-05]
# Epoch 41 Train Loss: 1.1230
# Epoch 42/50 [Mask: 8, α: 1.6]: 100% 32/32 [00:56<00:00,  1.76s/it, loss=1.32, lr=6.1e-05]
# Epoch 42 Train Loss: 1.0346
#   ➜ [Val] Loss: 0.9594 | RMSE: 933.28 | CPC: 0.5319
# Epoch 43/50 [Mask: 9, α: 1.4]: 100% 32/32 [00:56<00:00,  1.76s/it, loss=0.859, lr=4.7e-05]
# Epoch 43 Train Loss: 0.9197
# Epoch 44/50 [Mask: 9, α: 1.2]: 100% 32/32 [00:55<00:00,  1.75s/it, loss=0.843, lr=3.5e-05]
# Epoch 44 Train Loss: 0.8214
#   ➜ [Val] Loss: 0.9526 | RMSE: 932.86 | CPC: 0.5347
# Epoch 45/50 [Mask: 9, α: 1.0]: 100% 32/32 [00:55<00:00,  1.75s/it, loss=0.681, lr=2.4e-05]
# Epoch 45 Train Loss: 0.7302
# Epoch 46/50 [Mask: 9, α: 1.0]: 100% 32/32 [00:56<00:00,  1.75s/it, loss=0.659, lr=1.6e-05]
# Epoch 46 Train Loss: 0.7146
#   ➜ [Val] Loss: 0.9406 | RMSE: 931.26 | CPC: 0.5379
# Epoch 47/50 [Mask: 9, α: 1.0]: 100% 32/32 [00:55<00:00,  1.74s/it, loss=0.655, lr=8.8e-06]
# Epoch 47 Train Loss: 0.7215
# Epoch 48/50 [Mask: 9, α: 1.0]: 100% 32/32 [00:55<00:00,  1.74s/it, loss=0.705, lr=3.9e-06]
# Epoch 48 Train Loss: 0.7181
#   ➜ [Val] Loss: 0.9310 | RMSE: 931.58 | CPC: 0.5392
# Epoch 49/50 [Mask: 9, α: 1.0]: 100% 32/32 [00:55<00:00,  1.75s/it, loss=0.688, lr=9.5e-07]
# Epoch 49 Train Loss: 0.7079
# Epoch 50/50 [Mask: 10, α: 1.0]: 100% 32/32 [00:55<00:00,  1.74s/it, loss=0.817, lr=3.0e-09]
# Epoch 50 Train Loss: 0.7189
#   ➜ [Val] Loss: 0.9429 | RMSE: 931.92 | CPC: 0.5378
# Training finished.
# Using device: cuda
# Loaded best_model_mae1.pth for testing.
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/kt/KTDB/src/model/train.py", line 247, in <module>
#     main()
#   File "/content/drive/MyDrive/kt/KTDB/src/model/train.py", line 38, in main
#     train_dl_model(args, train_dataset, test_dataset)
#   File "/content/drive/MyDrive/kt/KTDB/src/model/train.py", line 192, in train_dl_model
#     test_dl_model(args, test_dataset)
#   File "/content/drive/MyDrive/kt/KTDB/src/model/model_test.py", line 100, in test_dl_model
#     pred = model(x_static, x_od_masked, x_dist, mask)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/kt/KTDB/src/model/models.py", line 214, in forward
#     col_feat = x_od_masked.transpose(1, 2)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: Dimension out of range (expected to be in range of [-2, 1], but got 2)

# %%
# !ls
# Out:
# best_model_mae1.pth  README.md	       results_mae1.png
# dataset		     requirements.txt  src

# %%
# !cp best_model_mae1.pth /content/drive/MyDrive/kt/KTDB/models

# %%
# 1. 모델 코드가 있는 디렉토리로 이동 (필수: 가중치 파일 위치를 맞추기 위함)
# %cd /content/drive/MyDrive/kt/KTDB/src/model
# 2. best weight를 불러와서 테스트 및 시각화 수행
# !python model_test.py --model mae1
# Out:
# /content/drive/MyDrive/kt/KTDB/src/model
# Dataset 초기화 완료
# Using device: cuda
# Loaded best_model_mae1.pth for testing.
#
# === Test Results (mae1) ===
# Test Loss (Weighted MSE log-scale): 1.0197
# RMSE (Real scale): 924.49
# CPC (Common Part of Commuters): 0.5434
# Visualization saved to results_mae1.png
