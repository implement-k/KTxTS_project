# %% [markdown]
# # KTDB OD 예측 모델 학습

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
# 내 구글 드라이브의 KTDB/src/model 폴더로 이동 
os.chdir('/content/drive/MyDrive/kt/KTDB')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### XGBoost 모델 학습

# %%
# !python train.py --model xgb --epochs 100 --batch_size 64

# %% [markdown]
# ### Deep Gravity 모델 학습

# %%
# !python train.py --model deep_gravity --epochs 50 --batch_size 128

# %% [markdown]
# ### Spatial OD MAE 모델 학습

# %%
# !python src/model/train.py --model mae1 --epochs 50 --batch_size 32
# Out:
# Starting main...
# Dataset 초기화 완료
# Dataset 초기화 완료
# Using device: cuda
# Epoch 1/50 [Max Mask: 2]: 100% 32/32 [01:54<00:00,  3.58s/it, loss=40.5]
# Epoch 1 Train Loss: 35.3390
# Epoch 2/50 [Max Mask: 2]: 100% 32/32 [01:55<00:00,  3.61s/it, loss=33.6]
# Epoch 2 Train Loss: 32.2663
#   ➜ [Val] Loss: 34.1738 | RMSE: 985.71 | CPC: 0.0156
#   ➜ [Checkpoint] Best model saved! (RMSE: 985.71)
# Epoch 3/50 [Max Mask: 2]: 100% 32/32 [01:53<00:00,  3.56s/it, loss=30.4]
# Epoch 3 Train Loss: 29.1128
# Epoch 4/50 [Max Mask: 2]: 100% 32/32 [01:55<00:00,  3.62s/it, loss=21.4]
# Epoch 4 Train Loss: 25.2198
#   ➜ [Val] Loss: 21.2917 | RMSE: 985.50 | CPC: 0.0635
#   ➜ [Checkpoint] Best model saved! (RMSE: 985.50)
# Epoch 5/50 [Max Mask: 2]: 100% 32/32 [01:55<00:00,  3.60s/it, loss=20.8]
# Epoch 5 Train Loss: 20.4121
# Epoch 6/50 [Max Mask: 2]: 100% 32/32 [01:55<00:00,  3.60s/it, loss=14.1]
# Epoch 6 Train Loss: 16.0481
#   ➜ [Val] Loss: 13.1974 | RMSE: 984.68 | CPC: 0.1458
#   ➜ [Checkpoint] Best model saved! (RMSE: 984.68)
# Epoch 7/50 [Max Mask: 2]: 100% 32/32 [01:53<00:00,  3.56s/it, loss=12]
# Epoch 7 Train Loss: 13.1379
# Epoch 8/50 [Max Mask: 3]: 100% 32/32 [01:55<00:00,  3.60s/it, loss=10.4]
# Epoch 8 Train Loss: 11.3157
#   ➜ [Val] Loss: 11.3954 | RMSE: 984.47 | CPC: 0.1803
#   ➜ [Checkpoint] Best model saved! (RMSE: 984.47)
# Epoch 9/50 [Max Mask: 3]: 100% 32/32 [01:54<00:00,  3.58s/it, loss=9.67]
# Epoch 9 Train Loss: 10.0569
# Epoch 10/50 [Max Mask: 3]: 100% 32/32 [01:55<00:00,  3.61s/it, loss=7.4]
# Epoch 10 Train Loss: 9.0756
#   ➜ [Val] Loss: 10.3637 | RMSE: 984.56 | CPC: 0.1900
# Epoch 11/50 [Max Mask: 3]: 100% 32/32 [01:53<00:00,  3.55s/it, loss=8.89]
# Epoch 11 Train Loss: 8.7254
# Epoch 12/50 [Max Mask: 3]: 100% 32/32 [01:54<00:00,  3.57s/it, loss=7.71]
# Epoch 12 Train Loss: 8.5102
#   ➜ [Val] Loss: 10.0031 | RMSE: 984.50 | CPC: 0.1923
# Epoch 13/50 [Max Mask: 3]: 100% 32/32 [01:54<00:00,  3.58s/it, loss=8.61]
# Epoch 13 Train Loss: 8.3479
# Epoch 14/50 [Max Mask: 4]: 100% 32/32 [01:54<00:00,  3.59s/it, loss=7.72]
# Epoch 14 Train Loss: 7.9283
#   ➜ [Val] Loss: 10.1875 | RMSE: 984.51 | CPC: 0.1966
# Epoch 15/50 [Max Mask: 4]: 100% 32/32 [01:56<00:00,  3.64s/it, loss=7.62]
# Epoch 15 Train Loss: 7.6619
# Epoch 16/50 [Max Mask: 4]: 100% 32/32 [01:53<00:00,  3.55s/it, loss=7.89]
# Epoch 16 Train Loss: 7.5393
#   ➜ [Val] Loss: 9.2334 | RMSE: 984.23 | CPC: 0.1952
#   ➜ [Checkpoint] Best model saved! (RMSE: 984.23)
# Epoch 17/50 [Max Mask: 4]: 100% 32/32 [01:56<00:00,  3.64s/it, loss=5.84]
# Epoch 17 Train Loss: 7.2075
# Epoch 18/50 [Max Mask: 4]: 100% 32/32 [01:56<00:00,  3.64s/it, loss=8.54]
# Epoch 18 Train Loss: 7.0652
#   ➜ [Val] Loss: 8.3276 | RMSE: 983.79 | CPC: 0.2237
#   ➜ [Checkpoint] Best model saved! (RMSE: 983.79)
# Epoch 19/50 [Max Mask: 4]: 100% 32/32 [01:54<00:00,  3.56s/it, loss=6.8]
# Epoch 19 Train Loss: 6.7684
# Epoch 20/50 [Max Mask: 5]: 100% 32/32 [01:54<00:00,  3.59s/it, loss=5.93]
# Epoch 20 Train Loss: 6.2133
#   ➜ [Val] Loss: 8.1135 | RMSE: 983.56 | CPC: 0.2238
#   ➜ [Checkpoint] Best model saved! (RMSE: 983.56)
# Epoch 21/50 [Max Mask: 5]: 100% 32/32 [01:53<00:00,  3.56s/it, loss=5.35]
# Epoch 21 Train Loss: 5.7328
# Epoch 22/50 [Max Mask: 5]: 100% 32/32 [01:53<00:00,  3.55s/it, loss=6.01]
# Epoch 22 Train Loss: 5.5769
#   ➜ [Val] Loss: 8.5444 | RMSE: 983.38 | CPC: 0.2182
#   ➜ [Checkpoint] Best model saved! (RMSE: 983.38)
# Epoch 23/50 [Max Mask: 5]: 100% 32/32 [01:55<00:00,  3.62s/it, loss=5.13]
# Epoch 23 Train Loss: 5.0818
# Epoch 24/50 [Max Mask: 5]: 100% 32/32 [01:57<00:00,  3.67s/it, loss=4.85]
# Epoch 24 Train Loss: 4.7571
#   ➜ [Val] Loss: 6.9636 | RMSE: 982.63 | CPC: 0.2526
#   ➜ [Checkpoint] Best model saved! (RMSE: 982.63)
# Epoch 25/50 [Max Mask: 5]: 100% 32/32 [01:55<00:00,  3.61s/it, loss=4.51]
# Epoch 25 Train Loss: 4.5388
# Epoch 26/50 [Max Mask: 6]: 100% 32/32 [01:55<00:00,  3.62s/it, loss=4.36]
# Epoch 26 Train Loss: 4.1452
#   ➜ [Val] Loss: 6.4622 | RMSE: 982.73 | CPC: 0.2602
# Epoch 27/50 [Max Mask: 6]: 100% 32/32 [01:55<00:00,  3.60s/it, loss=4.14]
# Epoch 27 Train Loss: 3.8871
# Epoch 28/50 [Max Mask: 6]: 100% 32/32 [01:54<00:00,  3.59s/it, loss=3.61]
# Epoch 28 Train Loss: 3.6323
#   ➜ [Val] Loss: 6.1064 | RMSE: 981.49 | CPC: 0.2733
#   ➜ [Checkpoint] Best model saved! (RMSE: 981.49)
# Epoch 29/50 [Max Mask: 6]: 100% 32/32 [01:54<00:00,  3.58s/it, loss=3.47]
# Epoch 29 Train Loss: 3.4875
# Epoch 30/50 [Max Mask: 6]: 100% 32/32 [01:55<00:00,  3.60s/it, loss=3.34]
# Epoch 30 Train Loss: 3.3326
#   ➜ [Val] Loss: 6.8838 | RMSE: 981.86 | CPC: 0.2539
# Epoch 31/50 [Max Mask: 6]: 100% 32/32 [01:55<00:00,  3.62s/it, loss=3.14]
# Epoch 31 Train Loss: 3.0999
# Epoch 32/50 [Max Mask: 7]: 100% 32/32 [01:54<00:00,  3.59s/it, loss=2.84]
# Epoch 32 Train Loss: 2.8351
#   ➜ [Val] Loss: 7.3890 | RMSE: 981.43 | CPC: 0.2357
#   ➜ [Checkpoint] Best model saved! (RMSE: 981.43)
# Epoch 33/50 [Max Mask: 7]: 100% 32/32 [01:54<00:00,  3.58s/it, loss=2.46]
# Epoch 33 Train Loss: 2.6165
# Epoch 34/50 [Max Mask: 7]: 100% 32/32 [01:54<00:00,  3.58s/it, loss=2.19]
# Epoch 34 Train Loss: 2.3993
#   ➜ [Val] Loss: 8.4886 | RMSE: 980.72 | CPC: 0.2332
#   ➜ [Checkpoint] Best model saved! (RMSE: 980.72)
# Epoch 35/50 [Max Mask: 7]: 100% 32/32 [01:54<00:00,  3.59s/it, loss=2.37]
# Epoch 35 Train Loss: 2.2896
# Epoch 36/50 [Max Mask: 7]: 100% 32/32 [01:54<00:00,  3.59s/it, loss=2.33]
# Epoch 36 Train Loss: 2.1534
#   ➜ [Val] Loss: 6.8955 | RMSE: 977.86 | CPC: 0.2500
#   ➜ [Checkpoint] Best model saved! (RMSE: 977.86)
# Epoch 37/50 [Max Mask: 7]: 100% 32/32 [01:56<00:00,  3.63s/it, loss=1.84]
# Epoch 37 Train Loss: 2.0112
# Epoch 38/50 [Max Mask: 8]: 100% 32/32 [01:55<00:00,  3.59s/it, loss=1.75]
# Epoch 38 Train Loss: 1.9245
#   ➜ [Val] Loss: 7.1163 | RMSE: 976.79 | CPC: 0.2406
#   ➜ [Checkpoint] Best model saved! (RMSE: 976.79)
# Epoch 39/50 [Max Mask: 8]: 100% 32/32 [01:56<00:00,  3.64s/it, loss=1.66]
# Epoch 39 Train Loss: 1.8635
# Epoch 40/50 [Max Mask: 8]: 100% 32/32 [01:54<00:00,  3.59s/it, loss=1.88]
# Epoch 40 Train Loss: 1.8157
#   ➜ [Val] Loss: 7.6544 | RMSE: 976.01 | CPC: 0.2201
#   ➜ [Checkpoint] Best model saved! (RMSE: 976.01)
# Epoch 41/50 [Max Mask: 8]: 100% 32/32 [01:54<00:00,  3.59s/it, loss=1.69]
# Epoch 41 Train Loss: 1.7716
# Epoch 42/50 [Max Mask: 8]: 100% 32/32 [01:55<00:00,  3.62s/it, loss=1.59]
# Epoch 42 Train Loss: 1.7403
#   ➜ [Val] Loss: 8.0031 | RMSE: 974.36 | CPC: 0.2529
#   ➜ [Checkpoint] Best model saved! (RMSE: 974.36)
# Epoch 43/50 [Max Mask: 8]: 100% 32/32 [01:55<00:00,  3.62s/it, loss=1.68]
# Epoch 43 Train Loss: 1.7057
# Epoch 44/50 [Max Mask: 9]: 100% 32/32 [01:55<00:00,  3.60s/it, loss=1.88]
# Epoch 44 Train Loss: 1.6733
#   ➜ [Val] Loss: 7.7460 | RMSE: 971.70 | CPC: 0.2501
#   ➜ [Checkpoint] Best model saved! (RMSE: 971.70)
# Epoch 45/50 [Max Mask: 9]: 100% 32/32 [01:56<00:00,  3.63s/it, loss=1.55]
# Epoch 45 Train Loss: 1.6456
# Epoch 46/50 [Max Mask: 9]: 100% 32/32 [01:58<00:00,  3.69s/it, loss=1.62]
# Epoch 46 Train Loss: 1.6401
#   ➜ [Val] Loss: 7.3750 | RMSE: 965.59 | CPC: 0.2522
#   ➜ [Checkpoint] Best model saved! (RMSE: 965.59)
# Epoch 47/50 [Max Mask: 9]: 100% 32/32 [01:57<00:00,  3.67s/it, loss=1.63]
# Epoch 47 Train Loss: 1.6035
# Epoch 48/50 [Max Mask: 9]: 100% 32/32 [01:56<00:00,  3.63s/it, loss=1.41]
# Epoch 48 Train Loss: 1.6239
#   ➜ [Val] Loss: 7.5963 | RMSE: 966.96 | CPC: 0.2459
# Epoch 49/50 [Max Mask: 9]: 100% 32/32 [01:55<00:00,  3.61s/it, loss=1.49]
# Epoch 49 Train Loss: 1.5876
# Epoch 50/50 [Max Mask: 10]: 100% 32/32 [01:55<00:00,  3.61s/it, loss=1.5]
# Epoch 50 Train Loss: 1.5606
#   ➜ [Val] Loss: 8.1739 | RMSE: 967.31 | CPC: 0.2570
# Loaded best model for testing.
#
# === Test Results (mae1) ===
# Test Loss (Weighted MSE log-scale): 7.4549
# RMSE (Real scale): 965.53
# CPC (Common Part of Commuters): 0.2505
# Visualization saved to results_mae1.png
